# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('hockney.jpg')
img_cvt=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_cvt)
plt.show()

# %%
# Converting RGB image to Grayscale
gray = cv2.cvtColor(img_cvt, cv2.COLOR_RGB2GRAY)

plt.imshow(gray)
plt.show()

# %%
type(gray) # ndarray
print(gray)
print(gray.shape)
# Out:
# [[141 143 146 ... 113 125 149]
#  [152 152 152 ... 125 131 150]
#  [154 155 155 ... 131 130 145]
#  ...
#  [ 87  88 104 ...  33  36  37]
#  [ 87  90 100 ...  33  36  36]
#  [ 87  89  92 ...  33  35  36]]
# (263, 192)

# %%
gray = cv2.resize(gray, (256,256))
plt.imshow(gray)
plt.show()

# %%
gray.shape
# Out:
# (256, 256)

# %%
# Function to calculate R1 and R2
def getRvals(img, L):
    
    # Initialization
    R1 = 0
    R2 = 0
    Wdth = img.shape[0]
    Hght = img.shape[1]
    
    for i in range(0, Hght):
        for j in range(0, Wdth):
            
            R1 += pow(-1, i + j) * img[i][j]
            R2 += pow(-1, i + j + 1) * img[i][j]

    return abs(R1//(Hght*L)), abs(R2//(Wdth*L))

# %%
L = 64 # Assumed in paper
R1, R2 = getRvals(gray, L)
R1, R2
# Out:
# (1, 0)
